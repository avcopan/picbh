# %%
from picbh import cbh, graph
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 from picbh import cbh, graph
#
# File ~/code/graph/picbh/src/picbh/cbh.py:13
#      10 import itertools
#      11 from collections import defaultdict
# ---> 13 from .graph.base import neighborhood
#      14 from .graph.mol import MolGraph, bond_orders, capped_subgraph, from_smiles, inchi
#      16 _H2_INCHI = inchi(from_smiles("[H][H]"))
#
# ImportError: cannot import name 'neighborhood' from 'picbh.graph.base' (/home/avcopan/code/graph/picbh/src/picbh/graph/base.py)

# %%
gra = graph.from_smiles("CSCCC(N)C(O)=O")
graph.rdkit_mol(gra, label=True)

# %%
cbh.expansion(gra, rung=1)

# %%
{rung: cbh.expansion(gra, rung=rung) for rung in range(5)}
